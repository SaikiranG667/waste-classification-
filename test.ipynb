# %%
import pickle

# %%
model=pickle.load(open('model', 'rb'))

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
img_path = 'R_10876.jpg'  
img = image.load_img(img_path, target_size=(224, 224))

# %%
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 223.5, 223.5, -0.5)

# %%
img_array = image.img_to_array(img)

# %%
img_array = np.expand_dims(img_array, axis=0)

# %%
def predict(img):
  value=model.predict(img_array)
  if value>0.5:
    print("Recyclable")
  else:
    print("Other")

# %%
predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Recyclable

# %%
img_path_2 = 'O_12624.jpg'  
img_2 = image.load_img(img_path_2, target_size=(224, 224))

# %%
plt.imshow(img_2)
plt.axis("off")
# Out:
# (-0.5, 223.5, 223.5, -0.5)

# %%
img_array = image.img_to_array(img_2)

# %%
img_array = np.expand_dims(img_array, axis=0)

# %%
predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Other
